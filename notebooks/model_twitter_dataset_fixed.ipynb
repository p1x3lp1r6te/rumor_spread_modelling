# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, InputLayer
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import tensorflow as tf
import math
import os


CSV_PATH = "twitter_dataset_fixed.csv"   # path used in this session
WINDOW_SIZE = 35
TEST_SPLIT = 0.30         # fraction held out for test (25%)
BATCH_SIZE = 32
EPOCHS = 100
PATIENCE = 10             # early stopping patience
LSTM_UNITS = 32           # smaller to avoid overfitting
L2_REG = 1e-4
DROPOUT = 0.2
RECURRENT_DROPOUT = 0.1
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)


# ---- 1) Load and preprocess ----
df = pd.read_csv(CSV_PATH)
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values('date').reset_index(drop=True)
df_index = df['date']  # keep for plotting if needed


df = df[['total_tweets', 'rumor_tweets', 'non_rumor_tweets']]

values = df.values.astype('float32')

# We'll create sequences but fit scaler only on training rows to avoid leakage.
def create_sequences_from_scaled(scaled_arr, window):
    X, y = [], []
    for i in range(len(scaled_arr) - window):
        X.append(scaled_arr[i:i+window])         # window x features (3)
        y.append(scaled_arr[i+window])           # full 3 values (we'll select target later)
    return np.array(X), np.array(y)             # X: (N, window, 3), y: (N, 3)


num_rows = len(values)
split_idx = int((1 - TEST_SPLIT) * num_rows)


scaler = MinMaxScaler()
scaler.fit(values[:split_idx])  
scaled_all = scaler.transform(values)

X_all, y_all = create_sequences_from_scaled(scaled_all, WINDOW_SIZE)

seq_split = split_idx - WINDOW_SIZE
if seq_split <= 0:
    raise ValueError("Not enough train rows for chosen WINDOW_SIZE. Reduce WINDOW_SIZE or use more data.")

X_train, X_test = X_all[:seq_split], X_all[seq_split:]
y_train, y_test = y_all[:seq_split], y_all[seq_split:]

print("Shapes: X_train", X_train.shape, "X_test", X_test.shape, "y_train", y_train.shape, "y_test", y_test.shape)

target_cols = ['total_tweets', 'rumor_tweets', 'non_rumor_tweets']
target_indices = [0, 1, 2]

def build_lstm_model(input_shape):
    model = Sequential([
        InputLayer(input_shape=input_shape),
        LSTM(LSTM_UNITS, kernel_regularizer=l2(L2_REG), recurrent_dropout=RECURRENT_DROPOUT),
        Dropout(DROPOUT),
        Dense(16, activation='relu', kernel_regularizer=l2(L2_REG)),
        Dense(1, activation='linear')
    ])
    model.compile(optimizer='adam', loss='mse')
    return model

es = EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=max(3, PATIENCE//3), min_lr=1e-6, verbose=1)

models = {}
histories = {}
results = {}
preds_test_scaled = {}

for col, idx in zip(target_cols, target_indices):
    print("\n\n=== Training model for target:", col, "===\n")
    y_tr = y_train[:, idx]  # scaled values
    y_te = y_test[:, idx]
    model = build_lstm_model((WINDOW_SIZE, 3))
    history = model.fit(
        X_train, y_tr,
        validation_data=(X_test, y_te),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=[es, rlr],
        verbose=2
    )
    models[col] = model
    histories[col] = history
    # predictions (scaled)
    y_pred_scaled = model.predict(X_test, verbose=0).reshape(-1)
    preds_test_scaled[col] = y_pred_scaled

    # plot loss
    plt.figure(figsize=(8,4))
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.title(f"Loss ({col})")
    plt.xlabel("Epoch")
    plt.ylabel("MSE")
    plt.legend()
    plt.grid(True)
    plt.show()

preds_scaled_matrix = np.stack([preds_test_scaled['total_tweets'],
                                preds_test_scaled['rumor_tweets'],
                                preds_test_scaled['non_rumor_tweets']], axis=1)  # shape (N_test, 3)

y_test_unscaled = scaler.inverse_transform(y_test)            # true (N_test, 3)
preds_unscaled = scaler.inverse_transform(preds_scaled_matrix)  # (N_test, 3)

def rmse(a,b): return math.sqrt(mean_squared_error(a,b))

for i, col in enumerate(target_cols):
    y_true = y_test_unscaled[:, i]
    y_pred = preds_unscaled[:, i]
    mae = mean_absolute_error(y_true, y_pred)
    r_mse = rmse(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    results[col] = {'MAE': mae, 'RMSE': r_mse, 'R2': r2}
    print(f"\nMetrics for {col}: MAE={mae:.3f}, RMSE={r_mse:.3f}, R2={r2:.3f}")

total_pred = preds_unscaled[:, 0]
rumor_pred = preds_unscaled[:, 1]
nonrumor_pred = preds_unscaled[:, 2]

diff = total_pred - (rumor_pred + nonrumor_pred)
print("\nSum relation (pred_total - (pred_rumor + pred_nonrumor)) statistics:")
print(" mean difference:", np.mean(diff))
print(" std difference :", np.std(diff))
print(" max abs diff   :", np.max(np.abs(diff)))
print(" min diff       :", np.min(diff))

diff_rounded = np.round(total_pred) - (np.round(rumor_pred) + np.round(nonrumor_pred))
pct_exact_equal = np.mean(diff_rounded == 0) * 100.0
print(f"After rounding to integers, % exact equality = {pct_exact_equal:.2f}%")

preds_unscaled_consistent = preds_unscaled.copy()
preds_unscaled_consistent[:, 0] = preds_unscaled_consistent[:, 1] + preds_unscaled_consistent[:, 2]
adj_diff = preds_unscaled_consistent[:, 0] - total_pred
print("Post-hoc adjust: mean change to total:", np.mean(adj_diff), "max change:", np.max(np.abs(adj_diff)))

import matplotlib.dates as mdates

seq_target_dates = df_index[WINDOW_SIZE:].reset_index(drop=True)   # length == len(y_all)
test_dates = seq_target_dates[seq_split:].reset_index(drop=True)   # dates corresponding to y_test

Nplot = min(200, len(y_test_unscaled))
plot_dates = test_dates[:Nplot]

fig, axes = plt.subplots(3, 1, figsize=(16, 10), sharex=True)

for i, col in enumerate(target_cols):
    axes[i].plot(plot_dates, y_test_unscaled[:Nplot, i], label=f"{col} (true)", linewidth=1.5)
    axes[i].plot(plot_dates, preds_unscaled[:Nplot, i], label=f"{col} (pred)", linestyle='--', alpha=0.9)
    axes[i].set_ylabel("Count")
    axes[i].legend()
    axes[i].grid(True)

axes[-1].set_xlabel("Date (timestamp)")
locator = mdates.AutoDateLocator(minticks=6, maxticks=12)
formatter = mdates.ConciseDateFormatter(locator)
axes[-1].xaxis.set_major_locator(locator)
axes[-1].xaxis.set_major_formatter(formatter)
plt.xticks(rotation=25)
plt.suptitle("True vs Predicted (test set) — timestamps on x-axis", fontsize=14)
plt.tight_layout(rect=[0, 0.03, 1, 0.96])
plt.show()


os.makedirs("trained_models_twitter", exist_ok=True)
for col, model in models.items():
    model.save(f"trained_models_twitter/lstm_{col}.keras")
print("\nSaved models to ./trained_models_twitter/")

print("\nSummary results:", results)
# Out:
# Shapes: X_train (603, 35, 3) X_test (274, 35, 3) y_train (603, 3) y_test (274, 3)
#
#
# === Training model for target: total_tweets ===
# C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch 1/100
# 19/19 - 5s - 272ms/step - loss: 0.0808 - val_loss: 0.0572 - learning_rate: 0.0010
# Epoch 2/100
# 19/19 - 1s - 37ms/step - loss: 0.0248 - val_loss: 0.0204 - learning_rate: 0.0010
# Epoch 3/100
# 19/19 - 0s - 21ms/step - loss: 0.0133 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 4/100
# 19/19 - 1s - 36ms/step - loss: 0.0090 - val_loss: 0.0069 - learning_rate: 0.0010
# Epoch 5/100
# 19/19 - 0s - 21ms/step - loss: 0.0083 - val_loss: 0.0064 - learning_rate: 0.0010
# Epoch 6/100
# 19/19 - 0s - 21ms/step - loss: 0.0083 - val_loss: 0.0066 - learning_rate: 0.0010
# Epoch 7/100
# 19/19 - 0s - 22ms/step - loss: 0.0067 - val_loss: 0.0060 - learning_rate: 0.0010
# Epoch 8/100
# 19/19 - 0s - 21ms/step - loss: 0.0070 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 9/100
# 19/19 - 0s - 21ms/step - loss: 0.0072 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 10/100
# 19/19 - 0s - 22ms/step - loss: 0.0056 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 11/100
# 19/19 - 0s - 20ms/step - loss: 0.0063 - val_loss: 0.0055 - learning_rate: 0.0010
# Epoch 12/100
# 19/19 - 1s - 37ms/step - loss: 0.0057 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 13/100
# 19/19 - 0s - 24ms/step - loss: 0.0057 - val_loss: 0.0054 - learning_rate: 0.0010
# Epoch 14/100
# 19/19 - 1s - 33ms/step - loss: 0.0054 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 15/100
# 19/19 - 0s - 21ms/step - loss: 0.0055 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 16/100
# 19/19 - 0s - 21ms/step - loss: 0.0054 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 17/100
# 19/19 - 0s - 22ms/step - loss: 0.0055 - val_loss: 0.0056 - learning_rate: 0.0010
# Epoch 18/100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 19/19 - 0s - 24ms/step - loss: 0.0059 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 19/100
# 19/19 - 0s - 21ms/step - loss: 0.0055 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 20/100
# 19/19 - 0s - 20ms/step - loss: 0.0053 - val_loss: 0.0049 - learning_rate: 5.0000e-04
# Epoch 21/100
# 19/19 - 0s - 20ms/step - loss: 0.0055 - val_loss: 0.0049 - learning_rate: 5.0000e-04
# Epoch 22/100
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 19/19 - 0s - 22ms/step - loss: 0.0051 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 23/100
# 19/19 - 1s - 34ms/step - loss: 0.0049 - val_loss: 0.0049 - learning_rate: 2.5000e-04
# Epoch 24/100
# 19/19 - 1s - 36ms/step - loss: 0.0048 - val_loss: 0.0047 - learning_rate: 2.5000e-04
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 19/19 - 0s - 22ms/step - loss: 0.0047 - val_loss: 0.0047 - learning_rate: 2.5000e-04
# Epoch 26/100
# 19/19 - 0s - 21ms/step - loss: 0.0049 - val_loss: 0.0047 - learning_rate: 1.2500e-04
# Epoch 27/100
# 19/19 - 0s - 22ms/step - loss: 0.0056 - val_loss: 0.0047 - learning_rate: 1.2500e-04
# Epoch 28/100
# 19/19 - 1s - 36ms/step - loss: 0.0050 - val_loss: 0.0047 - learning_rate: 1.2500e-04
# Epoch 29/100
# 19/19 - 0s - 21ms/step - loss: 0.0052 - val_loss: 0.0047 - learning_rate: 1.2500e-04
# Epoch 30/100
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 19/19 - 0s - 20ms/step - loss: 0.0050 - val_loss: 0.0047 - learning_rate: 1.2500e-04
# Epoch 31/100
# 19/19 - 0s - 20ms/step - loss: 0.0050 - val_loss: 0.0047 - learning_rate: 6.2500e-05
# Epoch 32/100
# 19/19 - 0s - 21ms/step - loss: 0.0052 - val_loss: 0.0047 - learning_rate: 6.2500e-05
# Epoch 33/100
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 19/19 - 0s - 21ms/step - loss: 0.0051 - val_loss: 0.0047 - learning_rate: 6.2500e-05
# Epoch 34/100
# 19/19 - 0s - 20ms/step - loss: 0.0050 - val_loss: 0.0047 - learning_rate: 3.1250e-05
# Epoch 35/100
# 19/19 - 0s - 20ms/step - loss: 0.0049 - val_loss: 0.0047 - learning_rate: 3.1250e-05
# Epoch 36/100
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 19/19 - 0s - 20ms/step - loss: 0.0051 - val_loss: 0.0047 - learning_rate: 3.1250e-05
# Epoch 37/100
# 19/19 - 0s - 21ms/step - loss: 0.0055 - val_loss: 0.0047 - learning_rate: 1.5625e-05
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 27.
# === Training model for target: rumor_tweets ===
#
# Epoch 1/100
# 19/19 - 5s - 246ms/step - loss: 0.0554 - val_loss: 0.0867 - learning_rate: 0.0010
# Epoch 2/100
# 19/19 - 0s - 21ms/step - loss: 0.0301 - val_loss: 0.0548 - learning_rate: 0.0010
# Epoch 3/100
# 19/19 - 0s - 20ms/step - loss: 0.0181 - val_loss: 0.0380 - learning_rate: 0.0010
# Epoch 4/100
# 19/19 - 0s - 20ms/step - loss: 0.0110 - val_loss: 0.0191 - learning_rate: 0.0010
# Epoch 5/100
# 19/19 - 0s - 21ms/step - loss: 0.0084 - val_loss: 0.0201 - learning_rate: 0.0010
# Epoch 6/100
# 19/19 - 0s - 20ms/step - loss: 0.0078 - val_loss: 0.0180 - learning_rate: 0.0010
# Epoch 7/100
# 19/19 - 0s - 20ms/step - loss: 0.0073 - val_loss: 0.0180 - learning_rate: 0.0010
# Epoch 8/100
# 19/19 - 0s - 19ms/step - loss: 0.0070 - val_loss: 0.0168 - learning_rate: 0.0010
# Epoch 9/100
# 19/19 - 0s - 21ms/step - loss: 0.0066 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 10/100
# 19/19 - 0s - 19ms/step - loss: 0.0062 - val_loss: 0.0154 - learning_rate: 0.0010
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 1.
# === Training model for target: non_rumor_tweets ===
#
# Epoch 1/100
# 19/19 - 5s - 247ms/step - loss: 0.1323 - val_loss: 0.0463 - learning_rate: 0.0010
# Epoch 2/100
# 19/19 - 0s - 20ms/step - loss: 0.0312 - val_loss: 0.0445 - learning_rate: 0.0010
# Epoch 3/100
# 19/19 - 0s - 20ms/step - loss: 0.0202 - val_loss: 0.0337 - learning_rate: 0.0010
# Epoch 4/100
# 19/19 - 0s - 20ms/step - loss: 0.0196 - val_loss: 0.0333 - learning_rate: 0.0010
# Epoch 5/100
# 19/19 - 0s - 20ms/step - loss: 0.0181 - val_loss: 0.0321 - learning_rate: 0.0010
# Epoch 6/100
# 19/19 - 0s - 20ms/step - loss: 0.0176 - val_loss: 0.0316 - learning_rate: 0.0010
# Epoch 7/100
# 19/19 - 0s - 20ms/step - loss: 0.0168 - val_loss: 0.0331 - learning_rate: 0.0010
# Epoch 8/100
# 19/19 - 0s - 20ms/step - loss: 0.0176 - val_loss: 0.0307 - learning_rate: 0.0010
# Epoch 9/100
# 19/19 - 0s - 20ms/step - loss: 0.0165 - val_loss: 0.0296 - learning_rate: 0.0010
# Epoch 10/100
# 19/19 - 0s - 19ms/step - loss: 0.0157 - val_loss: 0.0287 - learning_rate: 0.0010
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Metrics for total_tweets: MAE=199.879, RMSE=291.600, R2=0.953
#
# Metrics for rumor_tweets: MAE=935.215, RMSE=1577.580, R2=-0.223
#
# Metrics for non_rumor_tweets: MAE=502.226, RMSE=564.817, R2=-0.765
#
# Sum relation (pred_total - (pred_rumor + pred_nonrumor)) statistics:
#  mean difference: 1031.3031
#  std difference : 1026.6572
#  max abs diff   : 3282.4968
#  min diff       : 144.50671
# After rounding to integers, % exact equality = 0.00%
# Post-hoc adjust: mean change to total: -1031.3031 max change: 3282.4968
# Saved models to ./trained_models_twitter/
#
# Summary results: {'total_tweets': {'MAE': 199.87901, 'RMSE': 291.60001768261264, 'R2': 0.9533233046531677}, 'rumor_tweets': {'MAE': 935.21497, 'RMSE': 1577.5797919598235, 'R2': -0.22329318523406982}, 'non_rumor_tweets': {'MAE': 502.22638, 'RMSE': 564.8168674446612, 'R2': -0.7654680013656616}}
